# %%
import os
from os.path import join
import sys
import numpy as np
import matplotlib.pylab as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from notebook_utils import get_stage2_table, get_Q_table, plot_C_loss, plot_quality

# %%
stage2_table = get_stage2_table('./runs')

# %%
print len(stage2_table)
# Out:
# 1551

# %%
(__, t_PE), (__, t_SQ) = stage2_table.groupby('target', sort=True)

# %%
plot_C_loss(t_PE, 'PE')
plot_C_loss(t_SQ, 'SQ')

# %%
plot_quality(t_PE, t_SQ)
