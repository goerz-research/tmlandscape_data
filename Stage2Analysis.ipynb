# %%
import os
from os.path import join
import sys
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import QDYN

# %%
# %matplotlib inline

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from notebook_utils import get_stage1_table, get_stage2_table, get_Q_table, oct_overview, show_oct_summary_table

# %%
get_stage1_table = QDYN.memoize.memoize(get_stage1_table)
get_stage1_table.load('stage1_table.cache')
get_stage2_table = QDYN.memoize.memoize(get_stage2_table)
get_stage2_table.load('stage2_table.cache')

# %%
for T in [200, 100, 50, 20, 10, 5]:
    oct_overview(T, 'stage2', inline=True, scatter_size=0,
                 categories=['1freq_center', '1freq_random'],
                 table_loader=get_stage2_table)
# Out:
# ## T = 200 ns (RWA) ##
# * Concurrence and Loss -- PE
# /Users/goerz/jobs/ConstrainedTransmon/venv/lib/python2.7/site-packages/matplotlib/tri/triangulation.py:110: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   self._neighbors)
# * Quality
# * Weyl Chamber
# ## T = 100 ns (RWA) ##
# * Concurrence and Loss -- PE
# * Quality
# * Weyl Chamber
# ## T = 50 ns (RWA) ##
# * Concurrence and Loss -- PE
# * Quality
# * Weyl Chamber
# ## T = 20 ns (RWA) ##
# * Concurrence and Loss -- PE
# * Quality
# * Weyl Chamber
# ## T = 10 ns (RWA) ##
# * Concurrence and Loss -- PE
# * Quality
# * Weyl Chamber
# ## T = 5 ns (RWA) ##
# * Concurrence and Loss -- PE
# * Quality
# * Weyl Chamber

# %% [markdown]
# ## Achieved Gate Fidelities

# %%
show_oct_summary_table(oct_table_reader=get_stage2_table, stage1_table_reader=get_stage1_table)
# Out:
#                     min f-free error  f-free error   Q error  w2 [GHz]  wc [GHz]
# gate duration [ns]
# 5                           3.77e-04      3.88e-04  6.72e-03  6.00e+00  6.70e+00
# 10                          7.54e-04      7.59e-04  8.21e-04  6.00e+00  4.50e+00
# 20                          1.51e-03      1.51e-03  1.53e-03  6.00e+00  1.07e+01
# 50                          3.76e-03      3.76e-03  3.82e-03  6.00e+00  1.11e+01
# 100                         7.51e-03      7.51e-03 -1.16e+01  5.00e+00  9.10e+00
# 200                         1.49e-02      4.09e-01  1.50e-02  6.00e+00  1.11e+01
