# %% [markdown]
# # Optimization Results for full Set of Universal gates -- density matrix propagation

# %% [markdown]
# The total error for the entire set ("err(tot)") is the average over the error for the 5 optimized gates. We show the optimized pulses and population dynamics for the best results.

# %%
import os
from os.path import join
import sys
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import QDYN
from notebook_utils import prop_overview, get_stage4_table, get_rho_prop_table

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
get_stage4_table = QDYN.memoize.memoize(get_stage4_table)
get_stage4_table.load('stage4_table.cache')

# %% [markdown]
# In the tables below, the error with subscript `_H` are in Hilbert space, whereas the errors with subscript `_L` are in Liouville space.

# %%
prop_overview(T=50, rwa=True, rho=True, err_limit=1.0e-2,
              stage4_folder='stage4', stage_prop_folder='stage_prop_rho',
              table_loader=get_stage4_table)
# Out:
# ## T = 50 ns (RWA) ##
# Comparison of Gate Errors in Hilbert space and Liouville space:
# <table width="1350px" border="1" class="dataframe">
#   <colgroup>
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# </colgroup>
# <thead>
#     <tr style="text-align: right;">
#       <th>w1 [GHz]</th>
#       <th>w2 [GHz]</th>
#       <th>wc [GHz]</th>
#       <th>err_H(H_L)</th>
#       <th>err_L(H_L)</th>
#       <th>err_H(S_L)</th>
#       <th>err_L(S_L)</th>
# ...

# %%
prop_overview(T=20, rwa=True, rho=True, err_limit=1.0e-1,
              stage4_folder='stage4', stage_prop_folder='stage_prop_rho',
              table_loader=get_stage4_table)
# Out:
# ## T = 20 ns (RWA) ##
# Comparison of Gate Errors in Hilbert space and Liouville space:
# <table width="1350px" border="1" class="dataframe">
#   <colgroup>
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# </colgroup>
# <thead>
#     <tr style="text-align: right;">
#       <th>w1 [GHz]</th>
#       <th>w2 [GHz]</th>
#       <th>wc [GHz]</th>
#       <th>err_H(H_L)</th>
#       <th>err_L(H_L)</th>
#       <th>err_H(S_L)</th>
#       <th>err_L(S_L)</th>
# ...

# %%
prop_overview(T=10, rwa=True, rho=True, err_limit=1.0e-1,
              stage4_folder='stage4', stage_prop_folder='stage_prop_rho',
              table_loader=get_stage4_table)
# Out:
# ## T = 10 ns (RWA) ##
# Comparison of Gate Errors in Hilbert space and Liouville space:
# <table width="1350px" border="1" class="dataframe">
#   <colgroup>
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 50px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# <col span="1" style="width: 100px;">
# </colgroup>
# <thead>
#     <tr style="text-align: right;">
#       <th>w1 [GHz]</th>
#       <th>w2 [GHz]</th>
#       <th>wc [GHz]</th>
#       <th>err_H(H_L)</th>
#       <th>err_L(H_L)</th>
#       <th>err_H(S_L)</th>
#       <th>err_L(S_L)</th>
# ...
